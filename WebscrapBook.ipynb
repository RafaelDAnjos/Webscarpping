# %%
# !pip install psycopg2
# Out:
# ...
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.

# %%
import psycopg2

# %%
import pandas as pd

# %%
 conn = psycopg2.connect("dbname='webscrapping' user='postgres' host='localhost' password='123456'")

# %%
df = pd.read_csv("dados_ceasa.csv",";")
df2 = pd.read_csv("dados_ceagesp.csv",";")

# %%
from sqlalchemy import Table, MetaData, create_engine
engine = create_engine("postgresql://postgres:123456@localhost/webscrapping")

# %%
import sqlite3
conn_sqlite = sqlite3.connect('test.db')

# %%
print(df)
# Out:
#                          produtos     embalagem      Min      M.c      Max  \
# 0                           CACAO  KG              15,00    16,00    20,00
# 1                         CAMARAO  KG              25,00    30,00    32,00
# 2                          CAVALA  KG              11,00    11,00    11,00
# 3                         CORVINA  KG               6,00     8,00     9,00
# 4                         GAROUPA  KG              22,00    22,00    22,00
# 5                         MANJUBA  KG               2,00     2,50     3,00
# 6                         MERLUZA  KG              15,00    15,00    15,00
# 7                         MISTURA  KG               2,00     2,50     2,50
# 8                     OLHO DE BOI  KG              14,50    14,50    14,50
# 9                           PEROA  KG               3,00     3,50     4,00
# 10                     PESCADINHA  KG              10,00    10,00    10,00
# ...

# %%
#df.to_sql("dados_ceasa",engine)
df2.to_sql("dados_ceagesp",engine)

# %%
pd.read_sql('select * from dados_ceasa',engine)
# Out:
#        index                    produtos     embalagem      Min      M.c  \
# 0          0                       CACAO  KG              15,00    16,00
# 1          1                     CAMARAO  KG              25,00    30,00
# 2          2                      CAVALA  KG              11,00    11,00
# 3          3                     CORVINA  KG               6,00     8,00
# 4          4                     GAROUPA  KG              22,00    22,00
# 5          5                     MANJUBA  KG               2,00     2,50
# 6          6                     MERLUZA  KG              15,00    15,00
# 7          7                     MISTURA  KG               2,00     2,50
# 8          8                 OLHO DE BOI  KG              14,50    14,50
# 9          9                       PEROA  KG               3,00     3,50
# 10        10                  PESCADINHA  KG              10,00    10,00
# 11        11                       SARDA  KG              11,00    11,00
# ...
